# %%
import os

os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'
os.environ["CUDA_VISIBLE_DEVICES"]='0'

# %%
from utils.ocr import OcrEngine
import matplotlib.pyplot as plt

# %%
img = plt.imread("./temp/test_digit.jpg")
plt.imshow(img)

# %%
ocr_engine = OcrEngine("7seg_ocr.h5")
# Out:
# 1/1 [==============================] - 4s 4s/step

# %%
ocr_engine(img)
# Out:
# 1/1 [==============================] - 0s 31ms/step
# '267'
